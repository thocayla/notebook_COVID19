# %%
from code_to_import import *

# %%
hosp, rea, rad, dc_cumul, dc_non_cumul = data_to_plots()
display(hosp, rea, rad, dc_cumul, dc_non_cumul)
# Out:
# Choisissez les données que vous souhaitez visualiser :
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget
# A Jupyter Widget

# %%
plotData(hosp.value, rea.value, rad.value, dc_cumul.value, dc_non_cumul.value)
